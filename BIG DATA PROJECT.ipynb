# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
import numpy as np
from sklearn import preprocessing

# %%
import scipy.cluster.hierarchy as sch

# %%
df = pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                2022-08-20 17:59:51
# 3                                2022-08-23 13:52:36
# 4                                2022-08-23 14:02:49
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                2022-08-20 18:00:09             IP Address
# 3                                2022-08-23 13:53:01         Survey Preview
# 4                                2022-08-23 14:03:33         Survey Preview
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# 1  {"ImportId":"ipAddress"}  {"ImportId":"progress"}  {"ImportId":"duration"}
# 2            73.102.129.218                      100                       18
# 3                       NaN                      100                       25
# 4                       NaN                      100                       43
#
#                   Finished                                       RecordedDate  \
# 0                 Finished                                      Recorded Date
# 1  {"ImportId":"finished"}  {"ImportId":"recordedDate","timeZone":"America...
# 2                     True                                2022-08-20 18:00:10
# 3                     True                                2022-08-23 13:53:03
# 4                     True                                2022-08-23 14:03:34
#
#                  ResponseId                 RecipientLastName  ...  \
# 0               Response ID               Recipient Last Name  ...
# 1  {"ImportId":"_recordId"}  {"ImportId":"recipientLastName"}  ...
# 2         R_bKndddVbYvd0OWZ                               NaN  ...
# 3         R_1r2qkSsjr1bFVj4                               NaN  ...
# 4         R_VWh5xFzPTtclQkx                               NaN  ...
#
#                                                  Q16  \
# 0  I can do an excellent job on Luddy course-rela...
# 1                               {"ImportId":"QID17"}
# 2                                                NaN
# 3                                                NaN
# 4                                                Yes
#
#                                                Q17  \
# 0  I can learn the content taught my Luddy courses
# 1                             {"ImportId":"QID18"}
# 2                                              NaN
# 3                                              NaN
# 4                                               No
#
#                                                  Q14  \
# 0  I can earn a good grade in the Luddy courses t...
# 1                               {"ImportId":"QID15"}
# 2                                                NaN
# 3                                                NaN
# 4                                                 No
#
#                                                   Q6  \
# 0  For what course are you being asked to fill ou...
# 1                           {"ImportId":"QID7_TEXT"}
# 2                                                NaN
# 3                                               i222
# 4                                                NaN
#
#                                                Q10  \
# 0  How do you describe yourself? - Selected Choice
# 1                             {"ImportId":"QID10"}
# 2                                              NaN
# 3                        Non-binary / third gender
# 4                                              NaN
#
#                                           Q10_4_TEXT  \
# 0  How do you describe yourself? - Prefer to self...
# 1                        {"ImportId":"QID10_4_TEXT"}
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  Q11  \
# 0  Choose one or more races that you consider you...
# 1                               {"ImportId":"QID11"}
# 2                                                NaN
# 3                                 White or Caucasian
# 4                                                NaN
#
#                                              Q12.1  \
# 0  Are you of Spanish, Hispanic, or Latino origin?
# 1                             {"ImportId":"QID12"}
# 2                                              NaN
# 3                                               No
# 4                                              NaN
#
#                                     nationality  \
# 0  Are you a domestic or international student?
# 1                          {"ImportId":"QID24"}
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#                                                  Q22
# 0  Here is your completion code for this survey. ...
# 1                          {"ImportId":"QID23_TEXT"}
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 50 columns]

# %%
df.iloc[0,:]
# Out:
# StartDate                                                        Start Date
# EndDate                                                            End Date
# Status                                                        Response Type
# IPAddress                                                        IP Address
# Progress                                                           Progress
# Duration (in seconds)                                 Duration (in seconds)
# Finished                                                           Finished
# RecordedDate                                                  Recorded Date
# ResponseId                                                      Response ID
# RecipientLastName                                       Recipient Last Name
# RecipientFirstName                                     Recipient First Name
# RecipientEmail                                              Recipient Email
# ExternalReference                                   External Data Reference
# LocationLatitude                                          Location Latitude
# LocationLongitude                                        Location Longitude
# DistributionChannel                                    Distribution Channel
# UserLanguage                                                  User Language
# Luddy or not?                                      Are you a Luddy Student?
# other_department                  What is the name of your home department?
# luddy_department          If you are Luddy student, what is your home de...
# sense of belonging _1     Please rate your agreement with the following ...
# sense of belonging _2     Please rate your agreement with the following ...
# sense of belonging _3     Please rate your agreement with the following ...
# sense of belonging _4     Please rate your agreement with the following ...
# sense of belonging _5     Please rate your agreement with the following ...
# sense of belonging _6     Please rate your agreement with the following ...
# sense of belonging _7     Please rate your agreement with the following ...
# sense of belonging _8     Please rate your agreement with the following ...
# sense of belonging _9     Please rate your agreement with the following ...
# sense of belonging _10    Please rate your agreement with the following ...
# sense of belonging _11    Please rate your agreement with the following ...
# sense of belonging _12    Please rate your agreement with the following ...
# sense of belonging _13    Please rate your agreement with the following ...
# sense of belonging _14    Please rate your agreement with the following ...
# sense of belonging _15    Please rate your agreement with the following ...
# sense of belonging _16    Please rate your agreement with the following ...
# Q19                                     How many years have you been at IU?
# Q12                       I can master the content of the Luddy courses ...
# Q13                       I could master the content of even the most ch...
# Q15                       I can do a good job on all of my Luddy courses...
# Q16                       I can do an excellent job on Luddy course-rela...
# Q17                         I can learn the content taught my Luddy courses
# Q14                       I can earn a good grade in the Luddy courses t...
# Q6                        For what course are you being asked to fill ou...
# Q10                         How do you describe yourself? - Selected Choice
# Q10_4_TEXT                How do you describe yourself? - Prefer to self...
# Q11                       Choose one or more races that you consider you...
# Q12.1                       Are you of Spanish, Hispanic, or Latino origin?
# nationality                    Are you a domestic or international student?
# Q22                       Here is your completion code for this survey. ...
# Name: 0, dtype: object

# %%
# for doing analysis of all the questions in detail (sense of belonging)

# %%
df.iloc[0,20]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - People in the Luddy School notice when I am good at something'

# %%
df.iloc[0,21]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - Faculty and staff in the Luddy School value my opinions'

# %%
df.iloc[0,22]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - Other students in the Luddy School take my opinions seriously'

# %%
df.iloc[0,23]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - Most faculty and staff in the Luddy School are interested in me.'

# %%
df.iloc[0,24]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - There is at least one instructor or other faculty or staff member in the the Luddy School I can talk to if I have a problem.'

# %%
df.iloc[0,25]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - People in the Luddy School are friendly to me.'

# %%
df.iloc[0,26]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - Students in the Luddy School help each other to succeed.'

# %%
df.iloc[0,27]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - I am treated with as much respect as other students.'

# %%
df.iloc[0,28]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - I have a good relationship with other students in the Luddy School.'

# %%
df.iloc[0,29]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - I can really be myself in the Luddy School.'

# %%
df.iloc[0,30]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - The faculty and staff in the Luddy School  respect me.'

# %%
df.iloc[0,31]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - People in the Luddy School know I can do good work.'

# %%
df.iloc[0,32]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - The instructors in the Luddy School give me compliments when I do something well.'

# %%
df.iloc[0,33]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - I feel proud of belonging to the Luddy School.'

# %%
df.iloc[0,34]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - Other students in the Luddy School  like me the way I am.'

# %%
df.iloc[0,35]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - Faculty and staff in the Luddy School really want me to succeed.'

# %%
df.iloc[0,36]
# Out:
# 'How many years have you been at IU?'

# %%
df.iloc[0,37]
# Out:
# 'I can master the content of the Luddy courses I am taking this semester'

# %%
df.iloc[0,38]
# Out:
# 'I could master the content of even the most challenging Luddy courses if I try'

# %%
df.iloc[0,39]
# Out:
# 'I can do a good job on all of my Luddy courses if I do not give up'

# %%
df.iloc[0,40]
# Out:
# 'I can do an excellent job on Luddy course-related problems and tasks assigned this semester'

# %%
df.iloc[0,41]
# Out:
# 'I can learn the content taught my Luddy courses'

# %%
df.iloc[0,42]
# Out:
# 'I can earn a good grade in the Luddy courses that I am taking this semester'

# %%
df.iloc[0,43]
# Out:
# 'For what course are you being asked to fill out this survey?'

# %%
df.iloc[0,44]
# Out:
# 'How do you describe yourself? - Selected Choice'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 50 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   StartDate               241 non-null    object
#  1   EndDate                 241 non-null    object
#  2   Status                  241 non-null    object
#  3   IPAddress               237 non-null    object
#  4   Progress                241 non-null    object
#  5   Duration (in seconds)   241 non-null    object
#  6   Finished                241 non-null    object
#  7   RecordedDate            241 non-null    object
#  8   ResponseId              241 non-null    object
#  9   RecipientLastName       2 non-null      object
#  10  RecipientFirstName      2 non-null      object
#  11  RecipientEmail          2 non-null      object
#  12  ExternalReference       2 non-null      object
#  13  LocationLatitude        224 non-null    object
#  14  LocationLongitude       224 non-null    object
#  15  DistributionChannel     241 non-null    object
#  16  UserLanguage            241 non-null    object
#  17  Luddy or not?           234 non-null    object
#  18  other_department        47 non-null     object
#  19  luddy_department        187 non-null    object
#  20  sense of belonging _1   224 non-null    object
#  21  sense of belonging _2   224 non-null    object
#  22  sense of belonging _3   224 non-null    object
#  23  sense of belonging _4   224 non-null    object
#  24  sense of belonging _5   224 non-null    object
#  25  sense of belonging _6   224 non-null    object
#  26  sense of belonging _7   224 non-null    object
#  27  sense of belonging _8   224 non-null    object
#  28  sense of belonging _9   224 non-null    object
#  29  sense of belonging _10  223 non-null    object
#  30  sense of belonging _11  224 non-null    object
#  31  sense of belonging _12  224 non-null    object
#  32  sense of belonging _13  224 non-null    object
#  33  sense of belonging _14  223 non-null    object
#  34  sense of belonging _15  224 non-null    object
#  35  sense of belonging _16  224 non-null    object
#  36  Q19                     224 non-null    object
#  37  Q12                     226 non-null    object
#  38  Q13                     226 non-null    object
#  39  Q15                     226 non-null    object
#  40  Q16                     226 non-null    object
#  41  Q17                     226 non-null    object
#  42  Q14                     226 non-null    object
#  43  Q6                      224 non-null    object
#  44  Q10                     224 non-null    object
#  45  Q10_4_TEXT              2 non-null      object
#  46  Q11                     224 non-null    object
#  47  Q12.1                   224 non-null    object
#  48  nationality             2 non-null      object
#  49  Q22                     84 non-null     object
# dtypes: object(50)
# memory usage: 94.3+ KB

# %%
df.shape
# Out:
# (241, 50)

# %%
df5.head()
# Out:
#                                             StartDate  \
# 0                                          Start Date
# 1   {"ImportId":"startDate","timeZone":"America/De...
# 7                                 2022-08-26 12:52:18
# 8                                 2022-08-26 12:54:57
# 15                                2022-09-07 07:08:18
#
#                                               EndDate                 Status  \
# 0                                            End Date          Response Type
# 1   {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 7                                 2022-08-26 12:54:46             IP Address
# 8                                 2022-08-26 13:00:31             IP Address
# 15                                2022-09-07 07:10:07             IP Address
#
#                    IPAddress                 Progress  \
# 0                 IP Address                 Progress
# 1   {"ImportId":"ipAddress"}  {"ImportId":"progress"}
# 7             129.79.197.132                      100
# 8             129.79.197.132                      100
# 15            129.79.197.103                      100
#
#       Duration (in seconds)                 Finished  \
# 0     Duration (in seconds)                 Finished
# 1   {"ImportId":"duration"}  {"ImportId":"finished"}
# 7                       147                     True
# 8                       333                     True
# 15                      109                     True
#
#                                          RecordedDate  \
# 0                                       Recorded Date
# 1   {"ImportId":"recordedDate","timeZone":"America...
# 7                                 2022-08-26 12:54:46
# 8                                 2022-08-26 13:00:31
# 15                                2022-09-07 07:10:08
#
#                   ResponseId                 RecipientLastName  ...  \
# 0                Response ID               Recipient Last Name  ...
# 1   {"ImportId":"_recordId"}  {"ImportId":"recipientLastName"}  ...
# 7          R_Wp8wlDv12zOGQCd                               NaN  ...
# 8          R_3iwYJ8aZxeS8EH1                               NaN  ...
# 15         R_28YaIXHtfqaKXTZ                               NaN  ...
#
#                                                   Q16  \
# 0   I can do an excellent job on Luddy course-rela...
# 1                                {"ImportId":"QID17"}
# 7                                                 Yes
# 8                                                  No
# 15                                                Yes
#
#                                                 Q17  \
# 0   I can learn the content taught my Luddy courses
# 1                              {"ImportId":"QID18"}
# 7                                               Yes
# 8                                               Yes
# 15                                              Yes
#
#                                                   Q14  \
# 0   I can earn a good grade in the Luddy courses t...
# 1                                {"ImportId":"QID15"}
# 7                                                 Yes
# 8                                                  No
# 15                                                Yes
#
#                                                    Q6  \
# 0   For what course are you being asked to fill ou...
# 1                            {"ImportId":"QID7_TEXT"}
# 7                                         test survey
# 8                                         test survey
# 15                                               i453
#
#                                                 Q10  \
# 0   How do you describe yourself? - Selected Choice
# 1                              {"ImportId":"QID10"}
# 7                         Non-binary / third gender
# 8                                 Prefer not to say
# 15                                           Female
#
#                                            Q10_4_TEXT  \
# 0   How do you describe yourself? - Prefer to self...
# 1                         {"ImportId":"QID10_4_TEXT"}
# 7                                                 NaN
# 8                                                 NaN
# 15                                                NaN
#
#                                                   Q11  \
# 0   Choose one or more races that you consider you...
# 1                                {"ImportId":"QID11"}
# 7                                   Prefer not to say
# 8                                  White or Caucasian
# 15                                 White or Caucasian
#
#                                               Q12.1  \
# 0   Are you of Spanish, Hispanic, or Latino origin?
# 1                              {"ImportId":"QID12"}
# 7                                                No
# 8                                               Yes
# 15                                               No
#
#                                      nationality  \
# 0   Are you a domestic or international student?
# 1                           {"ImportId":"QID24"}
# 7                                            NaN
# 8                                            NaN
# 15                                           NaN
#
#                                                   Q22
# 0   Here is your completion code for this survey. ...
# 1                           {"ImportId":"QID23_TEXT"}
# 7                                                 NaN
# 8                                                 NaN
# 15                                                NaN
#
# [5 rows x 50 columns]

# %%
df.loc[df['Finished'] == 'True']
# Out:
#                StartDate              EndDate          Status       IPAddress  \
# 2    2022-08-20 17:59:51  2022-08-20 18:00:09      IP Address  73.102.129.218
# 3    2022-08-23 13:52:36  2022-08-23 13:53:01  Survey Preview             NaN
# 4    2022-08-23 14:02:49  2022-08-23 14:03:33  Survey Preview             NaN
# 5    2022-08-20 18:04:58  2022-08-23 15:15:53      IP Address  73.102.129.218
# 7    2022-08-26 12:52:18  2022-08-26 12:54:46      IP Address  129.79.197.132
# ..                   ...                  ...             ...             ...
# 236  2022-09-19 19:13:43  2022-09-19 19:16:08      IP Address  129.79.197.142
# 237  2022-09-19 20:05:11  2022-09-19 20:10:01      IP Address    68.50.18.208
# 238  2022-09-19 21:00:05  2022-09-19 21:03:57      IP Address   73.102.55.174
# 239  2022-09-19 21:14:37  2022-09-19 21:17:33      IP Address   66.244.80.109
# 240  2022-09-19 21:23:54  2022-09-19 21:30:34      IP Address    68.50.32.126
#
#     Progress Duration (in seconds) Finished         RecordedDate  \
# 2        100                    18     True  2022-08-20 18:00:10
# 3        100                    25     True  2022-08-23 13:53:03
# 4        100                    43     True  2022-08-23 14:03:34
# 5        100                249054     True  2022-08-23 15:15:53
# 7        100                   147     True  2022-08-26 12:54:46
# ..       ...                   ...      ...                  ...
# 236      100                   145     True  2022-09-19 19:16:09
# 237      100                   289     True  2022-09-19 20:10:01
# 238      100                   232     True  2022-09-19 21:03:57
# 239      100                   176     True  2022-09-19 21:17:33
# 240      100                   400     True  2022-09-19 21:30:34
#
#             ResponseId RecipientLastName  ...  Q16  Q17  Q14  \
# 2    R_bKndddVbYvd0OWZ               NaN  ...  NaN  NaN  NaN
# 3    R_1r2qkSsjr1bFVj4               NaN  ...  NaN  NaN  NaN
# 4    R_VWh5xFzPTtclQkx               NaN  ...  Yes   No   No
# 5    R_CmLRf9pq0acjmGl               NaN  ...  NaN  NaN  NaN
# 7    R_Wp8wlDv12zOGQCd               NaN  ...  Yes  Yes  Yes
# ..                 ...               ...  ...  ...  ...  ...
# 236  R_272vKAcbNo8CzBW               NaN  ...  Yes  Yes  Yes
# 237  R_3R91C3fW7xdpcsb               NaN  ...   No  Yes  Yes
# 238  R_21uLKGk2ALgjY9u               NaN  ...   No  Yes  Yes
# 239  R_2AHDmGsQ9DkUsPy               NaN  ...  Yes  Yes  Yes
# 240  R_zcF7QfZAdrjxdhD               NaN  ...   No  Yes  Yes
#
#                      Q6                        Q10 Q10_4_TEXT  \
# 2                   NaN                        NaN        NaN
# 3                  i222  Non-binary / third gender        NaN
# 4                   NaN                        NaN        NaN
# 5                   NaN                        NaN        NaN
# 7           test survey  Non-binary / third gender        NaN
# ..                  ...                        ...        ...
# 236   Applied Algorithm                       Male        NaN
# 237  Applied Algorithms                       Male        NaN
# 238  Applied Algorithms                       Male        NaN
# 239                B505                       Male        NaN
# 240  Applied Algorithms                       Male        NaN
#
#                     Q11 Q12.1 nationality           Q22
# 2                   NaN   NaN         NaN           NaN
# 3    White or Caucasian    No         NaN           NaN
# 4                   NaN   NaN         NaN           NaN
# 5                   NaN   NaN         NaN           NaN
# 7     Prefer not to say    No         NaN           NaN
# ..                  ...   ...         ...           ...
# 236               Asian    No         NaN           NaN
# 237               Asian    No         NaN  Q2LUD2F-5693
# 238               Asian    No         NaN  Q2LUD2F-1877
# 239               Asian    No         NaN           NaN
# 240               Asian    No         NaN           NaN
#
# [222 rows x 50 columns]

# %%
df.iloc[20]
# Out:
# StartDate                                     2022-09-07 07:08:35
# EndDate                                       2022-09-07 07:11:32
# Status                                                 IP Address
# IPAddress                                          149.159.220.25
# Progress                                                      100
# Duration (in seconds)                                         177
# Finished                                                     True
# RecordedDate                                  2022-09-07 07:11:32
# ResponseId                                      R_1l3HsfwGkXorbGI
# RecipientLastName                                             NaN
# RecipientFirstName                                            NaN
# RecipientEmail                                                NaN
# ExternalReference                                             NaN
# LocationLatitude                                          39.1707
# LocationLongitude                                         -86.519
# DistributionChannel                                     anonymous
# UserLanguage                                                   EN
# Luddy or not?             Yes, I am a student in the Luddy School
# other_department                                              NaN
# luddy_department                                      Informatics
# sense of belonging _1                  Neither agree nor disagree
# sense of belonging _2                  Neither agree nor disagree
# sense of belonging _3                  Neither agree nor disagree
# sense of belonging _4                  Neither agree nor disagree
# sense of belonging _5                              Somewhat agree
# sense of belonging _6                              Somewhat agree
# sense of belonging _7                              Somewhat agree
# sense of belonging _8                              Somewhat agree
# sense of belonging _9                              Somewhat agree
# sense of belonging _10                 Neither agree nor disagree
# sense of belonging _11                 Neither agree nor disagree
# sense of belonging _12                 Neither agree nor disagree
# sense of belonging _13                 Neither agree nor disagree
# sense of belonging _14                             Somewhat agree
# sense of belonging _15                 Neither agree nor disagree
# sense of belonging _16                             Somewhat agree
# Q19                                                     two years
# Q12                                                            No
# Q13                                                            No
# Q15                                                           Yes
# Q16                                                            No
# Q17                                                           Yes
# Q14                                                           Yes
# Q6                                computer and information ethics
# Q10                                                        Female
# Q10_4_TEXT                                                    NaN
# Q11                                            White or Caucasian
# Q12.1                                                          No
# nationality                                                   NaN
# Q22                                                           NaN
# Name: 20, dtype: object

# %%
 df = df.drop([df.index[0], df.index[1]])

# %%
df['Duration (in seconds)'].dtypes
# Out:
# dtype('O')

# %%
df = df.astype({"Duration (in seconds)": 'int'})

# %%
df['Duration (in seconds)'].dtypes
# Out:
# dtype('int64')

# %%
df.loc[df['Duration (in seconds)'] > 1200]
# Out:
#                StartDate              EndDate      Status       IPAddress  \
# 5    2022-08-20 18:04:58  2022-08-23 15:15:53  IP Address  73.102.129.218
# 6    2022-08-17 09:42:06  2022-08-17 14:07:08  IP Address    156.56.95.98
# 10   2022-08-24 07:39:47  2022-08-26 12:24:34  IP Address    156.56.95.98
# 11   2022-08-26 13:04:50  2022-08-26 13:27:07  IP Address  129.79.197.132
# 30   2022-09-07 09:39:37  2022-09-07 13:16:48  IP Address    66.244.84.63
# 52   2022-09-07 22:38:53  2022-09-10 11:53:08  IP Address  129.79.197.252
# 66   2022-09-11 10:15:24  2022-09-11 11:45:54  IP Address  129.79.197.174
# 90   2022-09-11 21:24:33  2022-09-11 21:59:40  IP Address  73.103.161.255
# 103  2022-09-13 18:00:32  2022-09-13 18:30:41  IP Address   68.54.134.196
# 116  2022-09-07 08:17:59  2022-09-13 22:51:53  IP Address   129.79.197.14
# 135  2022-09-07 13:19:23  2022-09-07 14:01:42  IP Address  129.79.197.206
# 136  2022-09-07 13:37:58  2022-09-07 14:17:35  IP Address   156.56.158.68
# 147  2022-09-05 09:19:30  2022-09-09 10:08:11  IP Address  73.102.129.218
# 152  2022-09-09 14:56:11  2022-09-10 06:43:53  IP Address     47.227.88.6
# 167  2022-09-11 12:32:35  2022-09-11 13:21:58  IP Address   129.79.197.51
# 230  2022-09-19 14:32:23  2022-09-19 15:40:32  IP Address  129.79.197.210
# 231  2022-09-19 14:36:44  2022-09-19 16:06:13  IP Address   129.79.197.30
#
#     Progress  Duration (in seconds) Finished         RecordedDate  \
# 5        100                 249054     True  2022-08-23 15:15:53
# 6         50                  15901    False  2022-08-24 14:07:09
# 10        13                 189887    False  2022-09-02 12:24:36
# 11        33                   1337    False  2022-09-02 13:27:08
# 30       100                  13031     True  2022-09-07 13:16:48
# 52       100                 220454     True  2022-09-10 11:53:08
# 66       100                   5429     True  2022-09-11 11:45:54
# 90       100                   2106     True  2022-09-11 21:59:40
# 103      100                   1808     True  2022-09-13 18:30:41
# 116      100                 570833     True  2022-09-13 22:51:53
# 135       94                   2539    False  2022-09-14 14:01:45
# 136       18                   2377    False  2022-09-14 14:17:38
# 147       76                 348520    False  2022-09-16 10:08:16
# 152       94                  56861    False  2022-09-17 06:43:54
# 167       76                   2962    False  2022-09-18 13:22:01
# 230      100                   4089     True  2022-09-19 15:40:33
# 231      100                   5369     True  2022-09-19 16:06:13
#
#             ResponseId RecipientLastName  ...  Q16  Q17  Q14  \
# 5    R_CmLRf9pq0acjmGl               NaN  ...  NaN  NaN  NaN
# 6    R_2S20nXLtLfB2Yyc               NaN  ...  NaN  NaN  NaN
# 10   R_1DHJGXUd7AIlWVO               NaN  ...  NaN  NaN  NaN
# 11   R_1gMVSzQp4k5C5uL               NaN  ...  NaN  NaN  NaN
# 30   R_Q5qWxn5hrnaAytj               NaN  ...  Yes  Yes  Yes
# 52   R_1FG2Net7tw9Eyxd               NaN  ...  Yes  Yes  Yes
# 66   R_3KClSs8T5nBsq3V               NaN  ...  Yes  Yes  Yes
# 90   R_25vA6z9bZYWAyY4               NaN  ...  Yes  Yes  Yes
# 103  R_3KZpMxCDUaA19Vw               NaN  ...  Yes  Yes  Yes
# 116  R_2rwtxWvkOJkevM0               NaN  ...  Yes  Yes  Yes
# 135  R_3mgZo6WLzAtDcxJ               NaN  ...  Yes  Yes  Yes
# 136  R_7ZFjOm21OH0VRo5               NaN  ...  NaN  NaN  NaN
# 147  R_1QgRCWzEvYhl69o               NaN  ...  NaN  NaN  NaN
# 152  R_1mIBFqs0mv0E2a0               NaN  ...  Yes  Yes  Yes
# 167  R_1OiNsFLJ9uUDIhx               NaN  ...  Yes  Yes  Yes
# 230  R_2EGeMSGeZZR8RmK               NaN  ...  Yes  Yes  Yes
# 231  R_OqYidHBejubEaAN               NaN  ...  Yes  Yes  Yes
#
#                                             Q6     Q10 Q10_4_TEXT  \
# 5                                          NaN     NaN        NaN
# 6                                          NaN     NaN        NaN
# 10                                         NaN     NaN        NaN
# 11                                         NaN     NaN        NaN
# 30              I-222, The information Society    Male        NaN
# 52                    The Information Society   Female        NaN
# 66                                        I222  Female        NaN
# 90                     FA22-BL-INFO-I222-12858    Male        NaN
# 103  FA22-BL-CSCI-B505-9361 Applied Algorithms  Female        NaN
# 116                   The Information society     Male        NaN
# 135                                        NaN    Male        NaN
# 136                                        NaN     NaN        NaN
# 147                                        NaN     NaN        NaN
# 152                    The Information Society    Male        NaN
# 167                        Information Society     NaN        NaN
# 230                               Data Fluency    Male        NaN
# 231                               Data Fluency    Male        NaN
#
#                     Q11 Q12.1 nationality           Q22
# 5                   NaN   NaN         NaN           NaN
# 6                   NaN   NaN         NaN           NaN
# 10                  NaN   NaN         NaN           NaN
# 11                  NaN   NaN         NaN           NaN
# 30   White or Caucasian    No         NaN     Thank you
# 52                Asian    No         NaN  Q2LUD2F-8077
# 66                Asian    No         NaN  Q2LUD2F-6142
# 90                Asian    No         NaN           NaN
# 103               Asian    No         NaN           NaN
# 116  White or Caucasian    No         NaN  Q2LUD2F-7210
# 135               Asian    No         NaN           NaN
# 136                 NaN   NaN         NaN           NaN
# 147                 NaN   NaN         NaN           NaN
# 152  White or Caucasian    No         NaN           NaN
# 167                 NaN   NaN         NaN           NaN
# 230  White or Caucasian    No         NaN           NaN
# 231  White or Caucasian    No         NaN           NaN
#
# [17 rows x 50 columns]

# %%
df.loc[df['Q16'].isna()]
# Out:
#                StartDate              EndDate          Status       IPAddress  \
# 2    2022-08-20 17:59:51  2022-08-20 18:00:09      IP Address  73.102.129.218
# 3    2022-08-23 13:52:36  2022-08-23 13:53:01  Survey Preview             NaN
# 5    2022-08-20 18:04:58  2022-08-23 15:15:53      IP Address  73.102.129.218
# 6    2022-08-17 09:42:06  2022-08-17 14:07:08      IP Address    156.56.95.98
# 10   2022-08-24 07:39:47  2022-08-26 12:24:34      IP Address    156.56.95.98
# 11   2022-08-26 13:04:50  2022-08-26 13:27:07      IP Address  129.79.197.132
# 12   2022-09-05 08:50:44  2022-09-05 08:51:35  Survey Preview             NaN
# 13   2022-09-05 09:08:09  2022-09-05 09:08:36  Survey Preview             NaN
# 14   2022-09-05 09:18:35  2022-09-05 09:19:22      IP Address  73.102.129.218
# 82   2022-09-11 18:54:08  2022-09-11 18:55:08      IP Address    68.50.12.222
# 123  2022-09-07 08:33:42  2022-09-07 08:35:14      IP Address   73.146.18.157
# 134  2022-09-07 13:38:12  2022-09-07 13:56:29      IP Address  129.79.197.206
# 136  2022-09-07 13:37:58  2022-09-07 14:17:35      IP Address   156.56.158.68
# 147  2022-09-05 09:19:30  2022-09-09 10:08:11      IP Address  73.102.129.218
# 218  2022-09-19 14:45:12  2022-09-19 14:46:18      IP Address  129.79.197.127
#
#     Progress  Duration (in seconds) Finished         RecordedDate  \
# 2        100                     18     True  2022-08-20 18:00:10
# 3        100                     25     True  2022-08-23 13:53:03
# 5        100                 249054     True  2022-08-23 15:15:53
# 6         50                  15901    False  2022-08-24 14:07:09
# 10        13                 189887    False  2022-09-02 12:24:36
# 11        33                   1337    False  2022-09-02 13:27:08
# 12       100                     51     True  2022-09-05 08:51:36
# 13       100                     26     True  2022-09-05 09:08:36
# 14       100                     47     True  2022-09-05 09:19:23
# 82       100                     60     True  2022-09-11 18:55:08
# 123       94                     92    False  2022-09-14 08:35:17
# 134       94                   1096    False  2022-09-14 13:56:32
# 136       18                   2377    False  2022-09-14 14:17:38
# 147       76                 348520    False  2022-09-16 10:08:16
# 218      100                     65     True  2022-09-19 14:46:18
#
#             ResponseId RecipientLastName  ...  Q16  Q17  Q14    Q6  \
# 2    R_bKndddVbYvd0OWZ               NaN  ...  NaN  NaN  NaN   NaN
# 3    R_1r2qkSsjr1bFVj4               NaN  ...  NaN  NaN  NaN  i222
# 5    R_CmLRf9pq0acjmGl               NaN  ...  NaN  NaN  NaN   NaN
# 6    R_2S20nXLtLfB2Yyc               NaN  ...  NaN  NaN  NaN   NaN
# 10   R_1DHJGXUd7AIlWVO               NaN  ...  NaN  NaN  NaN   NaN
# 11   R_1gMVSzQp4k5C5uL               NaN  ...  NaN  NaN  NaN   NaN
# 12   R_2s4t8cmylKgOb0I               NaN  ...  NaN  NaN  NaN   NaN
# 13   R_2dGz8yyEMWNE9ue               NaN  ...  NaN  NaN  NaN   NaN
# 14   R_1eWqPiwwjeHh7J5               NaN  ...  NaN  NaN  NaN   NaN
# 82   R_1HcKsi7FZJ5LIZZ               NaN  ...  NaN  NaN  NaN   NaN
# 123  R_2COFOtDDzw7OUeC               NaN  ...  NaN  NaN  NaN   NaN
# 134  R_bK0h7rDM3Gfh5PH               NaN  ...  NaN  NaN  NaN   NaN
# 136  R_7ZFjOm21OH0VRo5               NaN  ...  NaN  NaN  NaN   NaN
# 147  R_1QgRCWzEvYhl69o               NaN  ...  NaN  NaN  NaN   NaN
# 218  R_2ypVxASM5UvyLr3               NaN  ...  NaN  NaN  NaN   NaN
#
#                            Q10 Q10_4_TEXT                 Q11 Q12.1  \
# 2                          NaN        NaN                 NaN   NaN
# 3    Non-binary / third gender        NaN  White or Caucasian    No
# 5                          NaN        NaN                 NaN   NaN
# 6                          NaN        NaN                 NaN   NaN
# 10                         NaN        NaN                 NaN   NaN
# 11                         NaN        NaN                 NaN   NaN
# 12                         NaN        NaN                 NaN   NaN
# 13                         NaN        NaN                 NaN   NaN
# 14                         NaN        NaN                 NaN   NaN
# 82                         NaN        NaN                 NaN   NaN
# 123                        NaN        NaN                 NaN   NaN
# 134                        NaN        NaN                 NaN   NaN
# 136                        NaN        NaN                 NaN   NaN
# 147                        NaN        NaN                 NaN   NaN
# 218                        NaN        NaN                 NaN   NaN
#
#     nationality           Q22
# 2           NaN           NaN
# 3           NaN           NaN
# 5           NaN           NaN
# 6           NaN           NaN
# 10          NaN           NaN
# 11          NaN           NaN
# 12          NaN           NaN
# 13          NaN           NaN
# 14          NaN           NaN
# 82          NaN  Q2LUD2F-5393
# 123         NaN           NaN
# 134         NaN           NaN
# 136         NaN           NaN
# 147         NaN           NaN
# 218         NaN           NaN
#
# [15 rows x 50 columns]

# %%
df5=df.dropna(subset=[
'sense of belonging _5',
'sense of belonging _6',
'sense of belonging _7',
'sense of belonging _8',
'sense of belonging _10',
'sense of belonging _11',
'sense of belonging _14',
'sense of belonging _16',
'Q12',
'Q15',
'Q16'])
print(df5.head())
# Out:
#                                             StartDate  \
# 0                                          Start Date
# 1   {"ImportId":"startDate","timeZone":"America/De...
# 7                                 2022-08-26 12:52:18
# 8                                 2022-08-26 12:54:57
# 15                                2022-09-07 07:08:18
#
#                                               EndDate                 Status  \
# 0                                            End Date          Response Type
# 1   {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 7                                 2022-08-26 12:54:46             IP Address
# 8                                 2022-08-26 13:00:31             IP Address
# 15                                2022-09-07 07:10:07             IP Address
#
#                    IPAddress                 Progress  \
# 0                 IP Address                 Progress
# 1   {"ImportId":"ipAddress"}  {"ImportId":"progress"}
# 7             129.79.197.132                      100
# 8             129.79.197.132                      100
# 15            129.79.197.103                      100
#
#       Duration (in seconds)                 Finished  \
# 0     Duration (in seconds)                 Finished
# 1   {"ImportId":"duration"}  {"ImportId":"finished"}
# 7                       147                     True
# 8                       333                     True
# 15                      109                     True
#
#                                          RecordedDate  \
# 0                                       Recorded Date
# 1   {"ImportId":"recordedDate","timeZone":"America...
# 7                                 2022-08-26 12:54:46
# 8                                 2022-08-26 13:00:31
# 15                                2022-09-07 07:10:08
#
#                   ResponseId                 RecipientLastName  ...  \
# 0                Response ID               Recipient Last Name  ...
# 1   {"ImportId":"_recordId"}  {"ImportId":"recipientLastName"}  ...
# 7          R_Wp8wlDv12zOGQCd                               NaN  ...
# 8          R_3iwYJ8aZxeS8EH1                               NaN  ...
# 15         R_28YaIXHtfqaKXTZ                               NaN  ...
#
#                                                   Q16  \
# 0   I can do an excellent job on Luddy course-rela...
# 1                                {"ImportId":"QID17"}
# 7                                                 Yes
# 8                                                  No
# 15                                                Yes
#
#                                                 Q17  \
# 0   I can learn the content taught my Luddy courses
# 1                              {"ImportId":"QID18"}
# 7                                               Yes
# 8                                               Yes
# 15                                              Yes
#
#                                                   Q14  \
# 0   I can earn a good grade in the Luddy courses t...
# 1                                {"ImportId":"QID15"}
# 7                                                 Yes
# 8                                                  No
# 15                                                Yes
#
#                                                    Q6  \
# 0   For what course are you being asked to fill ou...
# 1                            {"ImportId":"QID7_TEXT"}
# 7                                         test survey
# 8                                         test survey
# 15                                               i453
#
#                                                 Q10  \
# 0   How do you describe yourself? - Selected Choice
# 1                              {"ImportId":"QID10"}
# 7                         Non-binary / third gender
# 8                                 Prefer not to say
# 15                                           Female
#
#                                            Q10_4_TEXT  \
# 0   How do you describe yourself? - Prefer to self...
# 1                         {"ImportId":"QID10_4_TEXT"}
# 7                                                 NaN
# 8                                                 NaN
# 15                                                NaN
#
#                                                   Q11  \
# 0   Choose one or more races that you consider you...
# 1                                {"ImportId":"QID11"}
# 7                                   Prefer not to say
# 8                                  White or Caucasian
# 15                                 White or Caucasian
#
#                                               Q12.1  \
# 0   Are you of Spanish, Hispanic, or Latino origin?
# 1                              {"ImportId":"QID12"}
# 7                                                No
# 8                                               Yes
# 15                                               No
#
#                                      nationality  \
# 0   Are you a domestic or international student?
# 1                           {"ImportId":"QID24"}
# 7                                            NaN
# 8                                            NaN
# 15                                           NaN
#
#                                                   Q22
# 0   Here is your completion code for this survey. ...
# 1                           {"ImportId":"QID23_TEXT"}
# 7                                                 NaN
# 8                                                 NaN
# 15                                                NaN
#
# [5 rows x 50 columns]

# %%
df5.iloc[0:,48]
# Out:
# 0      Are you a domestic or international student?
# 1                              {"ImportId":"QID24"}
# 7                                               NaN
# 8                                               NaN
# 15                                              NaN
#                            ...
# 236                                             NaN
# 237                                             NaN
# 238                                             NaN
# 239                                             NaN
# 240                                             NaN
# Name: nationality, Length: 222, dtype: object

# %%
df5.iloc[0:,49]
# Out:
# 0      Here is your completion code for this survey. ...
# 1                              {"ImportId":"QID23_TEXT"}
# 7                                                    NaN
# 8                                                    NaN
# 15                                                   NaN
#                              ...
# 236                                                  NaN
# 237                                         Q2LUD2F-5693
# 238                                         Q2LUD2F-1877
# 239                                                  NaN
# 240                                                  NaN
# Name: Q22, Length: 222, dtype: object

# %%
df15=df5.dropna(subset=[
'Q22'])
print(df15.head())
# Out:
#                                             StartDate  \
# 0                                          Start Date
# 1   {"ImportId":"startDate","timeZone":"America/De...
# 17                                2022-09-07 07:08:07
# 19                                2022-09-07 07:08:25
# 23                                2022-09-07 09:06:37
#
#                                               EndDate                 Status  \
# 0                                            End Date          Response Type
# 1   {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 17                                2022-09-07 07:10:39             IP Address
# 19                                2022-09-07 07:11:20             IP Address
# 23                                2022-09-07 09:09:35             IP Address
#
#                    IPAddress                 Progress  \
# 0                 IP Address                 Progress
# 1   {"ImportId":"ipAddress"}  {"ImportId":"progress"}
# 17            129.79.197.173                      100
# 19            129.79.197.177                      100
# 23            129.79.197.226                      100
#
#       Duration (in seconds)                 Finished  \
# 0     Duration (in seconds)                 Finished
# 1   {"ImportId":"duration"}  {"ImportId":"finished"}
# 17                      151                     True
# 19                      175                     True
# 23                      178                     True
#
#                                          RecordedDate  \
# 0                                       Recorded Date
# 1   {"ImportId":"recordedDate","timeZone":"America...
# 17                                2022-09-07 07:10:39
# 19                                2022-09-07 07:11:20
# 23                                2022-09-07 09:09:35
#
#                   ResponseId                 RecipientLastName  ...  \
# 0                Response ID               Recipient Last Name  ...
# 1   {"ImportId":"_recordId"}  {"ImportId":"recipientLastName"}  ...
# 17         R_3QKRvSUfvtQRAZB                               NaN  ...
# 19         R_3HgWeRXAZQt8IXD                               NaN  ...
# 23         R_2ykMzyVj0oOs66S                               NaN  ...
#
#                                                   Q16  \
# 0   I can do an excellent job on Luddy course-rela...
# 1                                {"ImportId":"QID17"}
# 17                                                Yes
# 19                                                Yes
# 23                                                Yes
#
#                                                 Q17  \
# 0   I can learn the content taught my Luddy courses
# 1                              {"ImportId":"QID18"}
# 17                                              Yes
# 19                                              Yes
# 23                                              Yes
#
#                                                   Q14  \
# 0   I can earn a good grade in the Luddy courses t...
# 1                                {"ImportId":"QID15"}
# 17                                                Yes
# 19                                                Yes
# 23                                                Yes
#
#                                                    Q6  \
# 0   For what course are you being asked to fill ou...
# 1                            {"ImportId":"QID7_TEXT"}
# 17                          Informatics Ethics - I453
# 19                                         Info I-453
# 23                       I222 The Information Society
#
#                                                 Q10  \
# 0   How do you describe yourself? - Selected Choice
# 1                              {"ImportId":"QID10"}
# 17                                             Male
# 19                                             Male
# 23                        Non-binary / third gender
#
#                                            Q10_4_TEXT  \
# 0   How do you describe yourself? - Prefer to self...
# 1                         {"ImportId":"QID10_4_TEXT"}
# 17                                                NaN
# 19                                                NaN
# 23                                                NaN
#
#                                                   Q11  \
# 0   Choose one or more races that you consider you...
# 1                                {"ImportId":"QID11"}
# 17                                 White or Caucasian
# 19                                 White or Caucasian
# 23                                 White or Caucasian
#
#                                               Q12.1  \
# 0   Are you of Spanish, Hispanic, or Latino origin?
# 1                              {"ImportId":"QID12"}
# 17                                               No
# 19                                               No
# 23                                               No
#
#                                      nationality  \
# 0   Are you a domestic or international student?
# 1                           {"ImportId":"QID24"}
# 17                                           NaN
# 19                                           NaN
# 23                                           NaN
#
#                                                   Q22
# 0   Here is your completion code for this survey. ...
# 1                           {"ImportId":"QID23_TEXT"}
# 17                                       Q2LUD2F-4917
# 19                                       Q2LUD2F-5570
# 23                                       Q2LUD2F-8272
#
# [5 rows x 50 columns]

# %%
df5.rename(columns = {'Luddy or not?':'luddyornot'},inplace = True)

# %%
luddy = df5.groupby(['luddyornot'])['luddyornot'].count().to_frame()
print(luddy)
# Out:
#                                                  luddyornot
# luddyornot
# Are you a Luddy Student?                                  1
# No, I am a student in another school/department          40
# Yes, I am a student in the Luddy School                 179
# {"ImportId":"QID8"}                                       1

# %%
plt.pie(luddy.luddyornot,colors = color,
       labels = luddy.index, startangle = 90 ,
       autopct = "%1.0f%%",
       explode = None, shadow = True)
plt.title("students studying in luddy or not")
plt.show()

# %%
# only 81 people completed full survey

# %%
df15.iloc[0:,49]
# Out:
# 0      Here is your completion code for this survey. ...
# 1                              {"ImportId":"QID23_TEXT"}
# 17                                          Q2LUD2F-4917
# 19                                          Q2LUD2F-5570
# 23                                          Q2LUD2F-8272
#                              ...
# 229                                         Q2LUD2F-6707
# 234                                         Q2LUD2F-1682
# 235                                         Q2LUD2F-4973
# 237                                         Q2LUD2F-5693
# 238                                         Q2LUD2F-1877
# Name: Q22, Length: 82, dtype: object

# %%
df5=df.dropna(subset=[
'sense of belonging _5',
'sense of belonging _6',
'sense of belonging _7',
'sense of belonging _8',
'sense of belonging _10',
'sense of belonging _11',
'sense of belonging _14',
'sense of belonging _16',
'Q12',
'Q15',
'Q16'])
print(df5.head())
# Out:
#                                             StartDate  \
# 0                                          Start Date
# 1   {"ImportId":"startDate","timeZone":"America/De...
# 7                                 2022-08-26 12:52:18
# 8                                 2022-08-26 12:54:57
# 15                                2022-09-07 07:08:18
#
#                                               EndDate                 Status  \
# 0                                            End Date          Response Type
# 1   {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 7                                 2022-08-26 12:54:46             IP Address
# 8                                 2022-08-26 13:00:31             IP Address
# 15                                2022-09-07 07:10:07             IP Address
#
#                    IPAddress                 Progress  \
# 0                 IP Address                 Progress
# 1   {"ImportId":"ipAddress"}  {"ImportId":"progress"}
# 7             129.79.197.132                      100
# 8             129.79.197.132                      100
# 15            129.79.197.103                      100
#
#       Duration (in seconds)                 Finished  \
# 0     Duration (in seconds)                 Finished
# 1   {"ImportId":"duration"}  {"ImportId":"finished"}
# 7                       147                     True
# 8                       333                     True
# 15                      109                     True
#
#                                          RecordedDate  \
# 0                                       Recorded Date
# 1   {"ImportId":"recordedDate","timeZone":"America...
# 7                                 2022-08-26 12:54:46
# 8                                 2022-08-26 13:00:31
# 15                                2022-09-07 07:10:08
#
#                   ResponseId                 RecipientLastName  ...  \
# 0                Response ID               Recipient Last Name  ...
# 1   {"ImportId":"_recordId"}  {"ImportId":"recipientLastName"}  ...
# 7          R_Wp8wlDv12zOGQCd                               NaN  ...
# 8          R_3iwYJ8aZxeS8EH1                               NaN  ...
# 15         R_28YaIXHtfqaKXTZ                               NaN  ...
#
#                                                   Q16  \
# 0   I can do an excellent job on Luddy course-rela...
# 1                                {"ImportId":"QID17"}
# 7                                                 Yes
# 8                                                  No
# 15                                                Yes
#
#                                                 Q17  \
# 0   I can learn the content taught my Luddy courses
# 1                              {"ImportId":"QID18"}
# 7                                               Yes
# 8                                               Yes
# 15                                              Yes
#
#                                                   Q14  \
# 0   I can earn a good grade in the Luddy courses t...
# 1                                {"ImportId":"QID15"}
# 7                                                 Yes
# 8                                                  No
# 15                                                Yes
#
#                                                    Q6  \
# 0   For what course are you being asked to fill ou...
# 1                            {"ImportId":"QID7_TEXT"}
# 7                                         test survey
# 8                                         test survey
# 15                                               i453
#
#                                                 Q10  \
# 0   How do you describe yourself? - Selected Choice
# 1                              {"ImportId":"QID10"}
# 7                         Non-binary / third gender
# 8                                 Prefer not to say
# 15                                           Female
#
#                                            Q10_4_TEXT  \
# 0   How do you describe yourself? - Prefer to self...
# 1                         {"ImportId":"QID10_4_TEXT"}
# 7                                                 NaN
# 8                                                 NaN
# 15                                                NaN
#
#                                                   Q11  \
# 0   Choose one or more races that you consider you...
# 1                                {"ImportId":"QID11"}
# 7                                   Prefer not to say
# 8                                  White or Caucasian
# 15                                 White or Caucasian
#
#                                               Q12.1  \
# 0   Are you of Spanish, Hispanic, or Latino origin?
# 1                              {"ImportId":"QID12"}
# 7                                                No
# 8                                               Yes
# 15                                               No
#
#                                      nationality  \
# 0   Are you a domestic or international student?
# 1                           {"ImportId":"QID24"}
# 7                                            NaN
# 8                                            NaN
# 15                                           NaN
#
#                                                   Q22
# 0   Here is your completion code for this survey. ...
# 1                           {"ImportId":"QID23_TEXT"}
# 7                                                 NaN
# 8                                                 NaN
# 15                                                NaN
#
# [5 rows x 50 columns]

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 0 to 240
# Data columns (total 50 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   StartDate               222 non-null    object
#  1   EndDate                 222 non-null    object
#  2   Status                  222 non-null    object
#  3   IPAddress               222 non-null    object
#  4   Progress                222 non-null    object
#  5   Duration (in seconds)   222 non-null    object
#  6   Finished                222 non-null    object
#  7   RecordedDate            222 non-null    object
#  8   ResponseId              222 non-null    object
#  9   RecipientLastName       2 non-null      object
#  10  RecipientFirstName      2 non-null      object
#  11  RecipientEmail          2 non-null      object
#  12  ExternalReference       2 non-null      object
#  13  LocationLatitude        212 non-null    object
#  14  LocationLongitude       212 non-null    object
#  15  DistributionChannel     222 non-null    object
#  16  UserLanguage            222 non-null    object
#  17  Luddy or not?           221 non-null    object
#  18  other_department        42 non-null     object
#  19  luddy_department        181 non-null    object
#  20  sense of belonging _1   222 non-null    object
#  21  sense of belonging _2   222 non-null    object
#  22  sense of belonging _3   222 non-null    object
#  23  sense of belonging _4   222 non-null    object
#  24  sense of belonging _5   222 non-null    object
#  25  sense of belonging _6   222 non-null    object
#  26  sense of belonging _7   222 non-null    object
#  27  sense of belonging _8   222 non-null    object
#  28  sense of belonging _9   222 non-null    object
#  29  sense of belonging _10  222 non-null    object
#  30  sense of belonging _11  222 non-null    object
#  31  sense of belonging _12  222 non-null    object
#  32  sense of belonging _13  222 non-null    object
#  33  sense of belonging _14  222 non-null    object
#  34  sense of belonging _15  222 non-null    object
#  35  sense of belonging _16  222 non-null    object
#  36  Q19                     220 non-null    object
#  37  Q12                     222 non-null    object
#  38  Q13                     222 non-null    object
#  39  Q15                     222 non-null    object
#  40  Q16                     222 non-null    object
#  41  Q17                     222 non-null    object
#  42  Q14                     222 non-null    object
#  43  Q6                      220 non-null    object
#  44  Q10                     220 non-null    object
#  45  Q10_4_TEXT              2 non-null      object
#  46  Q11                     220 non-null    object
#  47  Q12.1                   220 non-null    object
#  48  nationality             2 non-null      object
#  49  Q22                     82 non-null     object
# dtypes: object(50)
# memory usage: 88.5+ KB

# %%
df5.shape
# Out:
# (222, 50)

# %%
df5.head()
# Out:
#                                             StartDate  \
# 0                                          Start Date
# 1   {"ImportId":"startDate","timeZone":"America/De...
# 7                                 2022-08-26 12:52:18
# 8                                 2022-08-26 12:54:57
# 15                                2022-09-07 07:08:18
#
#                                               EndDate                 Status  \
# 0                                            End Date          Response Type
# 1   {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 7                                 2022-08-26 12:54:46             IP Address
# 8                                 2022-08-26 13:00:31             IP Address
# 15                                2022-09-07 07:10:07             IP Address
#
#                    IPAddress                 Progress  \
# 0                 IP Address                 Progress
# 1   {"ImportId":"ipAddress"}  {"ImportId":"progress"}
# 7             129.79.197.132                      100
# 8             129.79.197.132                      100
# 15            129.79.197.103                      100
#
#       Duration (in seconds)                 Finished  \
# 0     Duration (in seconds)                 Finished
# 1   {"ImportId":"duration"}  {"ImportId":"finished"}
# 7                       147                     True
# 8                       333                     True
# 15                      109                     True
#
#                                          RecordedDate  \
# 0                                       Recorded Date
# 1   {"ImportId":"recordedDate","timeZone":"America...
# 7                                 2022-08-26 12:54:46
# 8                                 2022-08-26 13:00:31
# 15                                2022-09-07 07:10:08
#
#                   ResponseId                 RecipientLastName  ...  \
# 0                Response ID               Recipient Last Name  ...
# 1   {"ImportId":"_recordId"}  {"ImportId":"recipientLastName"}  ...
# 7          R_Wp8wlDv12zOGQCd                               NaN  ...
# 8          R_3iwYJ8aZxeS8EH1                               NaN  ...
# 15         R_28YaIXHtfqaKXTZ                               NaN  ...
#
#                                                   Q16  \
# 0   I can do an excellent job on Luddy course-rela...
# 1                                {"ImportId":"QID17"}
# 7                                                 Yes
# 8                                                  No
# 15                                                Yes
#
#                                                 Q17  \
# 0   I can learn the content taught my Luddy courses
# 1                              {"ImportId":"QID18"}
# 7                                               Yes
# 8                                               Yes
# 15                                              Yes
#
#                                                   Q14  \
# 0   I can earn a good grade in the Luddy courses t...
# 1                                {"ImportId":"QID15"}
# 7                                                 Yes
# 8                                                  No
# 15                                                Yes
#
#                                                    Q6  \
# 0   For what course are you being asked to fill ou...
# 1                            {"ImportId":"QID7_TEXT"}
# 7                                         test survey
# 8                                         test survey
# 15                                               i453
#
#                                                 Q10  \
# 0   How do you describe yourself? - Selected Choice
# 1                              {"ImportId":"QID10"}
# 7                         Non-binary / third gender
# 8                                 Prefer not to say
# 15                                           Female
#
#                                            Q10_4_TEXT  \
# 0   How do you describe yourself? - Prefer to self...
# 1                         {"ImportId":"QID10_4_TEXT"}
# 7                                                 NaN
# 8                                                 NaN
# 15                                                NaN
#
#                                                   Q11  \
# 0   Choose one or more races that you consider you...
# 1                                {"ImportId":"QID11"}
# 7                                   Prefer not to say
# 8                                  White or Caucasian
# 15                                 White or Caucasian
#
#                                               Q12.1  \
# 0   Are you of Spanish, Hispanic, or Latino origin?
# 1                              {"ImportId":"QID12"}
# 7                                                No
# 8                                               Yes
# 15                                               No
#
#                                      nationality  \
# 0   Are you a domestic or international student?
# 1                           {"ImportId":"QID24"}
# 7                                            NaN
# 8                                            NaN
# 15                                           NaN
#
#                                                   Q22
# 0   Here is your completion code for this survey. ...
# 1                           {"ImportId":"QID23_TEXT"}
# 7                                                 NaN
# 8                                                 NaN
# 15                                                NaN
#
# [5 rows x 50 columns]

# %%
df5.iloc[0:,33]
# Out:
# 0      Please rate your agreement with the following ...
# 1                                 {"ImportId":"QID5_14"}
# 7                                         Strongly agree
# 8                             Neither agree nor disagree
# 15                                        Strongly agree
#                              ...
# 236                                    Somewhat disagree
# 237                                       Strongly agree
# 238                                       Somewhat agree
# 239                           Neither agree nor disagree
# 240                                       Somewhat agree
# Name: sense of belonging _14, Length: 222, dtype: object

# %%
df.iloc[0,33]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - I feel proud of belonging to the Luddy School.'

# %%
proud = df5.groupby(['feelproud'])['feelproud'].count().to_frame()
print(proud)
# Out:
#                                                     feelproud
# feelproud
# Neither agree nor disagree                                 48
# Please rate your agreement with the following s...          1
# Somewhat agree                                             86
# Somewhat disagree                                           3
# Strongly Disagree                                           2
# Strongly agree                                             81
# {"ImportId":"QID5_14"}                                      1

# %%
cmap = plt.get_cmap("tab20c")
color = cmap(np.array([1,3,5,6,9,10]))

# %%
df.rename(columns = {'feelproud':'sense of belonging _14'},inplace = True)

# %%
df5.rename(columns = {'sense of belonging _14':'feelproud'},inplace = True)

# %%
plt.pie(proud.feelproud,colors = color,
       labels = proud.index, startangle = 90 ,
       autopct = "%1.0f%%",
       explode = None, shadow = True)
plt.title("students who feels proud to study in LUDDY")
plt.show()

# %%
df5.iloc[0,40]
# Out:
# 'I can do an excellent job on Luddy course-related problems and tasks assigned this semester'

# %%
# co-relation between students doing excellent job on Luddy courses ralated problem and earning a good grade in the courses

# %%
def create_groups(
df5: df5, var1: str, var2: str)->df5:
    category = df5.groupby([var1,var2])[var2].count().to_frame()
    print('var1' + 'by' + 'var2')
    return category

# %%
create_groups(df5,'Q16','Q14')
# Out:
# Q16byQ14
#                                                                                                        Q14
# Q16                                                Q14
# I can do an excellent job on Luddy course-relat... I can earn a good grade in the Luddy courses th...    1
# No                                                 No                                                    4
#                                                    Yes                                                   9
# Yes                                                No                                                    3
#                                                    Yes                                                 204
# {"ImportId":"QID17"}                               {"ImportId":"QID15"}                                  1

# %% [markdown]
# # reflection of self confidence by Luddy Students (Q13)

# %%
df5.iloc[0,38]
# Out:
# 'I could master the content of even the most challenging Luddy courses if I try'

# %%
selfconfidence = df5.groupby(['Q13'])['Q13'].count().to_frame()
print(selfconfidence)

# %%
self1 = selfconfidence[1:-1]
print(self1)
# Out:
#      Q13
# Q13
# No    36
# Yes  184

# %%
self1.plot(kind="bar", title="Self confidence")
plt.title("Self confidence of LUDDY students")
plt.xlabel("response from Students")
plt.ylabel("countings")
# Out:
# Text(0, 0.5, 'countings')

# %%
# demographics analytics Q12.1 Are you of Spanish, Hispanic, or Latino origin?

# %%
df6.iloc[0:67,47]
# Out:
# 0     Are you of Spanish, Hispanic, or Latino origin?
# 1                                {"ImportId":"QID12"}
# 7                                                  No
# 8                                                 Yes
# 15                                                 No
#                            ...
# 74                                                 No
# 75                                                 No
# 76                                                 No
# 77                                                 No
# 78                                                 No
# Name: Q12.1, Length: 67, dtype: object

# %%
demographics = df6.groupby(['Q12.1'])['Q12.1'].count().to_frame()
print(demographics)
# Out:
#                                                  Q12.1
# Q12.1
# Are you of Spanish, Hispanic, or Latino origin?      1
# No                                                 207
# Yes                                                 11
# {"ImportId":"QID12"}                                 1

# %%
demographics1 = demographics[1:-1]
print(demographics1)
# Out:
#        Q12.1
# Q12.1
# No       207
# Yes       11

# %%
demographics1.plot(kind="bar", title="demographics")
plt.title("Are you of Spanish, Hispanic, or Latino origin?")
plt.xlabel("response from Students")
plt.ylabel("countings")
# Out:
# Text(0, 0.5, 'countings')

# %%
df6=df5.dropna(subset=[
'Q13'])
print(df6.head())
# Out:
#                                             StartDate  \
# 0                                          Start Date
# 1   {"ImportId":"startDate","timeZone":"America/De...
# 7                                 2022-08-26 12:52:18
# 8                                 2022-08-26 12:54:57
# 15                                2022-09-07 07:08:18
#
#                                               EndDate                 Status  \
# 0                                            End Date          Response Type
# 1   {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 7                                 2022-08-26 12:54:46             IP Address
# 8                                 2022-08-26 13:00:31             IP Address
# 15                                2022-09-07 07:10:07             IP Address
#
#                    IPAddress                 Progress  \
# 0                 IP Address                 Progress
# 1   {"ImportId":"ipAddress"}  {"ImportId":"progress"}
# 7             129.79.197.132                      100
# 8             129.79.197.132                      100
# 15            129.79.197.103                      100
#
#       Duration (in seconds)                 Finished  \
# 0     Duration (in seconds)                 Finished
# 1   {"ImportId":"duration"}  {"ImportId":"finished"}
# 7                       147                     True
# 8                       333                     True
# 15                      109                     True
#
#                                          RecordedDate  \
# 0                                       Recorded Date
# 1   {"ImportId":"recordedDate","timeZone":"America...
# 7                                 2022-08-26 12:54:46
# 8                                 2022-08-26 13:00:31
# 15                                2022-09-07 07:10:08
#
#                   ResponseId                 RecipientLastName  ...  \
# 0                Response ID               Recipient Last Name  ...
# 1   {"ImportId":"_recordId"}  {"ImportId":"recipientLastName"}  ...
# 7          R_Wp8wlDv12zOGQCd                               NaN  ...
# 8          R_3iwYJ8aZxeS8EH1                               NaN  ...
# 15         R_28YaIXHtfqaKXTZ                               NaN  ...
#
#                                                   Q16  \
# 0   I can do an excellent job on Luddy course-rela...
# 1                                {"ImportId":"QID17"}
# 7                                                 Yes
# 8                                                  No
# 15                                                Yes
#
#                                                 Q17  \
# 0   I can learn the content taught my Luddy courses
# 1                              {"ImportId":"QID18"}
# 7                                               Yes
# 8                                               Yes
# 15                                              Yes
#
#                                                   Q14  \
# 0   I can earn a good grade in the Luddy courses t...
# 1                                {"ImportId":"QID15"}
# 7                                                 Yes
# 8                                                  No
# 15                                                Yes
#
#                                                    Q6  \
# 0   For what course are you being asked to fill ou...
# 1                            {"ImportId":"QID7_TEXT"}
# 7                                         test survey
# 8                                         test survey
# 15                                               i453
#
#                                                 Q10  \
# 0   How do you describe yourself? - Selected Choice
# 1                              {"ImportId":"QID10"}
# 7                         Non-binary / third gender
# 8                                 Prefer not to say
# 15                                           Female
#
#                                            Q10_4_TEXT  \
# 0   How do you describe yourself? - Prefer to self...
# 1                         {"ImportId":"QID10_4_TEXT"}
# 7                                                 NaN
# 8                                                 NaN
# 15                                                NaN
#
#                                                   Q11  \
# 0   Choose one or more races that you consider you...
# 1                                {"ImportId":"QID11"}
# 7                                   Prefer not to say
# 8                                  White or Caucasian
# 15                                 White or Caucasian
#
#                                               Q12.1  \
# 0   Are you of Spanish, Hispanic, or Latino origin?
# 1                              {"ImportId":"QID12"}
# 7                                                No
# 8                                               Yes
# 15                                               No
#
#                                      nationality  \
# 0   Are you a domestic or international student?
# 1                           {"ImportId":"QID24"}
# 7                                            NaN
# 8                                            NaN
# 15                                           NaN
#
#                                                   Q22
# 0   Here is your completion code for this survey. ...
# 1                           {"ImportId":"QID23_TEXT"}
# 7                                                 NaN
# 8                                                 NaN
# 15                                                NaN
#
# [5 rows x 50 columns]

# %%
df5.iloc[0,23]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - Most faculty and staff in the Luddy School are interested in me.'

# %%
df5.iloc[0,21]
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - Faculty and staff in the Luddy School value my opinions'

# %%
faculty_interestedinstudentopinion = df5.groupby(['faculty_interestedinstudentopinion2'])['faculty_interestedinstudentopinion2'].count().to_frame()
print(faculty_interestedinstudentopinion)
# Out:
#                                                     faculty_interestedinstudentopinion2
# faculty_interestedinstudentopinion2
# Neither agree nor disagree                                                           84
# Please rate your agreement with the following s...                                    1
# Somewhat agree                                                                       74
# Somewhat disagree                                                                    23
# Strongly Disagree                                                                     5
# Strongly agree                                                                       34
# {"ImportId":"QID5_4"}                                                                 1

# %%
df5 = df10

# %%
df10 = df5
df5
# Out:
#                                              StartDate  \
# 0                                           Start Date
# 1    {"ImportId":"startDate","timeZone":"America/De...
# 7                                  2022-08-26 12:52:18
# 8                                  2022-08-26 12:54:57
# 15                                 2022-09-07 07:08:18
# ..                                                 ...
# 236                                2022-09-19 19:13:43
# 237                                2022-09-19 20:05:11
# 238                                2022-09-19 21:00:05
# 239                                2022-09-19 21:14:37
# 240                                2022-09-19 21:23:54
#
#                                                EndDate                 Status  \
# 0                                             End Date          Response Type
# 1    {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 7                                  2022-08-26 12:54:46             IP Address
# 8                                  2022-08-26 13:00:31             IP Address
# 15                                 2022-09-07 07:10:07             IP Address
# ..                                                 ...                    ...
# 236                                2022-09-19 19:16:08             IP Address
# 237                                2022-09-19 20:10:01             IP Address
# 238                                2022-09-19 21:03:57             IP Address
# 239                                2022-09-19 21:17:33             IP Address
# 240                                2022-09-19 21:30:34             IP Address
#
#                     IPAddress                 Progress  \
# 0                  IP Address                 Progress
# 1    {"ImportId":"ipAddress"}  {"ImportId":"progress"}
# 7              129.79.197.132                      100
# 8              129.79.197.132                      100
# 15             129.79.197.103                      100
# ..                        ...                      ...
# 236            129.79.197.142                      100
# 237              68.50.18.208                      100
# 238             73.102.55.174                      100
# 239             66.244.80.109                      100
# 240              68.50.32.126                      100
#
#        Duration (in seconds)                 Finished  \
# 0      Duration (in seconds)                 Finished
# 1    {"ImportId":"duration"}  {"ImportId":"finished"}
# 7                        147                     True
# 8                        333                     True
# 15                       109                     True
# ..                       ...                      ...
# 236                      145                     True
# 237                      289                     True
# 238                      232                     True
# 239                      176                     True
# 240                      400                     True
#
#                                           RecordedDate  \
# 0                                        Recorded Date
# 1    {"ImportId":"recordedDate","timeZone":"America...
# 7                                  2022-08-26 12:54:46
# 8                                  2022-08-26 13:00:31
# 15                                 2022-09-07 07:10:08
# ..                                                 ...
# 236                                2022-09-19 19:16:09
# 237                                2022-09-19 20:10:01
# 238                                2022-09-19 21:03:57
# 239                                2022-09-19 21:17:33
# 240                                2022-09-19 21:30:34
#
#                    ResponseId                 RecipientLastName  ...  \
# 0                 Response ID               Recipient Last Name  ...
# 1    {"ImportId":"_recordId"}  {"ImportId":"recipientLastName"}  ...
# 7           R_Wp8wlDv12zOGQCd                               NaN  ...
# 8           R_3iwYJ8aZxeS8EH1                               NaN  ...
# 15          R_28YaIXHtfqaKXTZ                               NaN  ...
# ..                        ...                               ...  ...
# 236         R_272vKAcbNo8CzBW                               NaN  ...
# 237         R_3R91C3fW7xdpcsb                               NaN  ...
# 238         R_21uLKGk2ALgjY9u                               NaN  ...
# 239         R_2AHDmGsQ9DkUsPy                               NaN  ...
# 240         R_zcF7QfZAdrjxdhD                               NaN  ...
#
#                                                    Q16  \
# 0    I can do an excellent job on Luddy course-rela...
# 1                                 {"ImportId":"QID17"}
# 7                                                  Yes
# 8                                                   No
# 15                                                 Yes
# ..                                                 ...
# 236                                                Yes
# 237                                                 No
# 238                                                 No
# 239                                                Yes
# 240                                                 No
#
#                                                  Q17  \
# 0    I can learn the content taught my Luddy courses
# 1                               {"ImportId":"QID18"}
# 7                                                Yes
# 8                                                Yes
# 15                                               Yes
# ..                                               ...
# 236                                              Yes
# 237                                              Yes
# 238                                              Yes
# 239                                              Yes
# 240                                              Yes
#
#                                                    Q14  \
# 0    I can earn a good grade in the Luddy courses t...
# 1                                 {"ImportId":"QID15"}
# 7                                                  Yes
# 8                                                   No
# 15                                                 Yes
# ..                                                 ...
# 236                                                Yes
# 237                                                Yes
# 238                                                Yes
# 239                                                Yes
# 240                                                Yes
#
#                                                     Q6  \
# 0    For what course are you being asked to fill ou...
# 1                             {"ImportId":"QID7_TEXT"}
# 7                                          test survey
# 8                                          test survey
# 15                                                i453
# ..                                                 ...
# 236                                  Applied Algorithm
# 237                                 Applied Algorithms
# 238                                 Applied Algorithms
# 239                                               B505
# 240                                 Applied Algorithms
#
#                                                  Q10  \
# 0    How do you describe yourself? - Selected Choice
# 1                               {"ImportId":"QID10"}
# 7                          Non-binary / third gender
# 8                                  Prefer not to say
# 15                                            Female
# ..                                               ...
# 236                                             Male
# 237                                             Male
# 238                                             Male
# 239                                             Male
# 240                                             Male
#
#                                             Q10_4_TEXT  \
# 0    How do you describe yourself? - Prefer to self...
# 1                          {"ImportId":"QID10_4_TEXT"}
# 7                                                  NaN
# 8                                                  NaN
# 15                                                 NaN
# ..                                                 ...
# 236                                                NaN
# 237                                                NaN
# 238                                                NaN
# 239                                                NaN
# 240                                                NaN
#
#                                                    Q11  \
# 0    Choose one or more races that you consider you...
# 1                                 {"ImportId":"QID11"}
# 7                                    Prefer not to say
# 8                                   White or Caucasian
# 15                                  White or Caucasian
# ..                                                 ...
# 236                                              Asian
# 237                                              Asian
# 238                                              Asian
# 239                                              Asian
# 240                                              Asian
#
#                                                Q12.1  \
# 0    Are you of Spanish, Hispanic, or Latino origin?
# 1                               {"ImportId":"QID12"}
# 7                                                 No
# 8                                                Yes
# 15                                                No
# ..                                               ...
# 236                                               No
# 237                                               No
# 238                                               No
# 239                                               No
# 240                                               No
#
#                                       nationality  \
# 0    Are you a domestic or international student?
# 1                            {"ImportId":"QID24"}
# 7                                             NaN
# 8                                             NaN
# 15                                            NaN
# ..                                            ...
# 236                                           NaN
# 237                                           NaN
# 238                                           NaN
# 239                                           NaN
# 240                                           NaN
#
#                                                    Q22
# 0    Here is your completion code for this survey. ...
# 1                            {"ImportId":"QID23_TEXT"}
# 7                                                  NaN
# 8                                                  NaN
# 15                                                 NaN
# ..                                                 ...
# 236                                                NaN
# 237                                       Q2LUD2F-5693
# 238                                       Q2LUD2F-1877
# 239                                                NaN
# 240                                                NaN
#
# [222 rows x 50 columns]

# %%
faculty_valuestudentopininon = df5.groupby(['faculty_valuestudentopininon2'])['faculty_valuestudentopininon2'].count().to_frame()
print(faculty_valuestudentopininon)
# Out:
#                                                     faculty_valuestudentopininon2
# faculty_valuestudentopininon2
# Neither agree nor disagree                                                     58
# Please rate your agreement with the following s...                              1
# Somewhat agree                                                                 91
# Somewhat disagree                                                               8
# Strongly Disagree                                                               2
# Strongly agree                                                                 61
# {"ImportId":"QID5_2"}                                                           1

# %%
create_groups(df5,'sense of belonging _4','sense of belonging _2')
# Out:
# var1byvar2
#                                                                                                        sense of belonging _2
# sense of belonging _4                              sense of belonging _2
# Neither agree nor disagree                         Neither agree nor disagree                                             34
#                                                    Somewhat agree                                                         32
#                                                    Strongly agree                                                         18
# Please rate your agreement with the following s... Please rate your agreement with the following s...                      1
# Somewhat agree                                     Neither agree nor disagree                                             11
#                                                    Somewhat agree                                                         44
#                                                    Strongly agree                                                         19
# Somewhat disagree                                  Neither agree nor disagree                                             10
#                                                    Somewhat agree                                                          6
#                                                    Somewhat disagree                                                       6
#                                                    Strongly Disagree                                                       1
# Strongly Disagree                                  Neither agree nor disagree                                              2
#                                                    Somewhat disagree                                                       2
#                                                    Strongly Disagree                                                       1
# Strongly agree                                     Neither agree nor disagree                                              1
#                                                    Somewhat agree                                                          9
#                                                    Strongly agree                                                         24
# {"ImportId":"QID5_4"}                              {"ImportId":"QID5_2"}                                                   1

# %%
df5.rename(columns = {'sense of belonging _4':'faculty_interestedinstudentopinion2'},inplace = True)

# %%
df5.rename(columns = {'sense of belonging _2':'faculty_valuestudentopininon2'},inplace = True)

# %%
cmap = plt.get_cmap("tab20c")
color = cmap(np.array([1,3,5,6,9,10]))

# %%
plt.pie(faculty_interestedinstudentopinion.faculty_interestedinstudentopinion2,colors = color,
       labels = faculty_interestedinstudentopinion.index, startangle = 90 ,
       autopct = "%1.0f%%",
       explode = None, shadow = True)
plt.title("Faculty intrested in student opinion")
plt.show()

# %%
treatedwithsamerespect = df5.groupby(['sense of belonging _8'])['sense of belonging _8'].count().to_frame()
print(treatedwithsamerespect)
# Out:
#                                                     sense of belonging _8
# sense of belonging _8
# Neither agree nor disagree                                             28
# Please rate your agreement with the following s...                      1
# Somewhat agree                                                         90
# Somewhat disagree                                                       3
# Strongly Disagree                                                       3
# Strongly agree                                                         96
# {"ImportId":"QID5_8"}                                                   1

# %%
# Out:
# 'Please rate your agreement with the following statements based on how you feel about the Luddy School. - I am treated with as much respect as other students.'

# %%
treatedwithsamerespect.plot.pie(figsize=(9,9),subplots=True)
# Out:
# array([<AxesSubplot:ylabel='sense of belonging _8'>], dtype=object)

# %%
facultyrespectme = df5.groupby(['sense of belonging _11'])['sense of belonging _11'].count().to_frame()
print(facultyrespectme)
# Out:
#                                                     sense of belonging _11
# sense of belonging _11
# Neither agree nor disagree                                              33
# Please rate your agreement with the following s...                       1
# Somewhat agree                                                          94
# Somewhat disagree                                                        4
# Strongly Disagree                                                        3
# Strongly agree                                                          86
# {"ImportId":"QID5_11"}                                                   1

# %%
plt.pie(faculty_valuestudentopininon.faculty_valuestudentopininon2,colors = color,
       labels = faculty_valuestudentopininon.index, startangle = 90 ,
       autopct = "%1.0f%%",
       explode = None, shadow = True)
plt.title("Faculty values  student opinion")
plt.show()

# %%
df5.iloc[51,1: ]
# Out:
# EndDate                                                            2022-09-11 10:33:38
# Status                                                                      IP Address
# IPAddress                                                                 129.79.197.1
# Progress                                                                           100
# Duration (in seconds)                                                              227
# Finished                                                                          True
# RecordedDate                                                       2022-09-11 10:33:40
# ResponseId                                                           R_2eWm9LbNeTdWoN3
# RecipientLastName                                                                  NaN
# RecipientFirstName                                                                 NaN
# RecipientEmail                                                                     NaN
# ExternalReference                                                                  NaN
# LocationLatitude                                                               39.1707
# LocationLongitude                                                              -86.519
# DistributionChannel                                                          anonymous
# UserLanguage                                                                        EN
# Luddy or not?                          No, I am a student in another school/department
# other_department                                             Kelley School of Business
# luddy_department                                                                   NaN
# sense of belonging _1                                                   Strongly agree
# faculty_valuestudentopininon2                                           Somewhat agree
# sense of belonging _3                                       Neither agree nor disagree
# faculty_interestedinstudentopinion2                         Neither agree nor disagree
# sense of belonging _5                                                   Somewhat agree
# sense of belonging _6                                                   Strongly agree
# sense of belonging _7                                                   Somewhat agree
# sense of belonging _8                                                   Strongly agree
# sense of belonging _9                                                   Strongly agree
# sense of belonging _10                                                  Somewhat agree
# sense of belonging _11                                                  Somewhat agree
# sense of belonging _12                                                  Somewhat agree
# sense of belonging _13                                      Neither agree nor disagree
# feelproud                                                   Neither agree nor disagree
# sense of belonging _15                                      Neither agree nor disagree
# sense of belonging _16                                                  Strongly agree
# Q19                                                                        three years
# Q12                                                                                 No
# Q13                                                                                Yes
# Q15                                                                                Yes
# Q16                                                                                Yes
# Q17                                                                                Yes
# Q14                                                                                Yes
# Q6                                                The Information Society [INFO-I-222]
# Q10                                                                             Female
# Q10_4_TEXT                                                                         NaN
# Q11                                                                              Asian
# Q12.1                                                                               No
# nationality                                                                        NaN
# Q22                                                                                NaN
# Name: 63, dtype: object

# %%
df = gene_input[['Sample1', 'Sample2', 'Sample4', 'Sample7']]

# %%
df20 = df5[['sense of belonging _5',
'sense of belonging _6',
'sense of belonging _7',
'sense of belonging _8',
'sense of belonging _10',
'sense of belonging _11',
'feelproud',
'sense of belonging _16',
]]

# %%
df21 = df20.iloc[2:,0:]

# %%
df31 = df20.iloc[2:,0:]

# %%
df21
# Out:
#           sense of belonging _5       sense of belonging _6  \
# 7                Strongly agree              Strongly agree
# 8    Neither agree nor disagree  Neither agree nor disagree
# 15               Strongly agree              Strongly agree
# 16               Somewhat agree              Somewhat agree
# 17               Strongly agree              Strongly agree
# ..                          ...                         ...
# 236              Somewhat agree           Somewhat disagree
# 237              Strongly agree              Strongly agree
# 238              Strongly agree              Strongly agree
# 239  Neither agree nor disagree           Somewhat disagree
# 240              Somewhat agree              Strongly agree
#
#           sense of belonging _7       sense of belonging _8  \
# 7                Strongly agree              Strongly agree
# 8    Neither agree nor disagree  Neither agree nor disagree
# 15               Somewhat agree              Strongly agree
# 16               Somewhat agree              Somewhat agree
# 17               Strongly agree              Strongly agree
# ..                          ...                         ...
# 236           Somewhat disagree           Somewhat disagree
# 237              Somewhat agree              Strongly agree
# 238              Somewhat agree              Strongly agree
# 239  Neither agree nor disagree  Neither agree nor disagree
# 240              Somewhat agree              Somewhat agree
#
#          sense of belonging _10      sense of belonging _11  \
# 7                Strongly agree              Strongly agree
# 8    Neither agree nor disagree  Neither agree nor disagree
# 15   Neither agree nor disagree              Strongly agree
# 16               Somewhat agree              Somewhat agree
# 17               Strongly agree              Strongly agree
# ..                          ...                         ...
# 236  Neither agree nor disagree           Somewhat disagree
# 237              Strongly agree              Strongly agree
# 238              Somewhat agree              Strongly agree
# 239           Somewhat disagree           Somewhat disagree
# 240              Somewhat agree              Somewhat agree
#
#                       feelproud      sense of belonging _16
# 7                Strongly agree              Strongly agree
# 8    Neither agree nor disagree  Neither agree nor disagree
# 15               Strongly agree              Strongly agree
# 16               Somewhat agree              Somewhat agree
# 17               Strongly agree              Strongly agree
# ..                          ...                         ...
# 236           Somewhat disagree           Somewhat disagree
# 237              Strongly agree              Strongly agree
# 238              Somewhat agree              Somewhat agree
# 239  Neither agree nor disagree           Somewhat disagree
# 240              Somewhat agree              Somewhat agree
#
# [220 rows x 8 columns]

# %%
label = preprocessing.LabelEncoder()
label.fit(df21['sense of belonging _6'])
# Out:
# LabelEncoder()

# %%
print(list(label.classes_))
print()
# Out:
# ['Neither agree nor disagree', 'Somewhat agree', 'Somewhat disagree', 'Strongly Disagree', 'Strongly agree']

# %%
mylist = (list(label.classes_))
myorder = [3, 2, 0, 1, 4]
label.classes_ = [mylist[i] for i in myorder]
print(label.classes_)
# Out:
# ['Strongly Disagree', 'Somewhat disagree', 'Neither agree nor disagree', 'Somewhat agree', 'Strongly agree']

# %%
print(label.transform(df21["sense of belonging _6"]))
# Out:
# [4 2 4 3 4 4 4 3 3 3 4 2 0 3 4 4 4 4 4 3 2 3 4 3 4 3 2 4 4 3 3 3 4 4 3 4 3
#  3 4 3 4 3 2 3 3 4 3 3 3 4 3 3 4 4 3 2 4 4 3 4 4 4 4 4 3 3 2 3 3 2 3 4 4 3
#  3 3 3 3 4 4 4 4 4 3 3 3 3 4 4 4 3 3 4 3 3 4 4 4 4 3 4 3 3 3 4 2 3 4 3 0 3
#  4 3 4 4 4 3 4 3 4 3 4 4 3 4 2 3 3 3 4 3 3 1 3 2 3 2 4 2 4 4 2 3 3 4 1 4 3
#  3 2 4 2 3 4 3 4 4 3 4 3 2 3 2 4 3 4 2 4 3 3 4 4 4 2 4 2 3 3 4 4 3 3 4 4 4
#  1 3 3 4 3 4 4 4 2 3 3 4 4 3 3 3 3 2 4 4 4 2 3 4 4 3 4 3 3 4 1 4 4 1 4]

# %%
df21['sense of belonging _5'] = df31['sense of belonging _5']

# %%
def createe_groups(
df21: df21, var1: str)->df21: 
    label = preprocessing.LabelEncoder()
    x = label.fit(df21[var1])        
    mylist = (list(label.classes_))
    myorder = [3, 2, 0, 1, 4]
    label.classes_ = [mylist[i] for i in myorder]
    return (label.transform(df21[var1]))

# %%
createe_groups(df21,'sense of belonging _5')
# Out:
# array([4, 2, 4, 3, 4, 4, 3, 3, 4, 3, 2, 2, 0, 3, 2, 3, 3, 4, 4, 3, 2, 4,
#        4, 3, 4, 2, 3, 4, 2, 1, 1, 1, 4, 4, 3, 4, 2, 3, 4, 3, 1, 4, 2, 2,
#        3, 4, 3, 2, 1, 3, 4, 2, 3, 4, 1, 2, 4, 3, 3, 2, 3, 3, 3, 4, 4, 3,
#        3, 3, 3, 2, 1, 4, 4, 3, 3, 3, 3, 3, 4, 4, 4, 2, 4, 0, 2, 1, 4, 4,
#        2, 4, 3, 4, 4, 2, 4, 3, 3, 3, 3, 3, 3, 2, 3, 3, 1, 3, 4, 3, 1, 1,
#        4, 4, 3, 4, 2, 4, 4, 4, 1, 4, 4, 3, 2, 3, 3, 0, 3, 3, 1, 4, 3, 3,
#        0, 3, 2, 2, 4, 2, 3, 4, 4, 2, 1, 1, 4, 0, 4, 3, 3, 2, 4, 4, 2, 4,
#        2, 3, 4, 3, 4, 4, 1, 1, 2, 4, 3, 4, 2, 3, 3, 3, 4, 4, 4, 2, 4, 2,
#        3, 3, 3, 1, 3, 4, 4, 4, 2, 3, 2, 2, 2, 2, 4, 4, 4, 2, 2, 3, 4, 2,
#        2, 3, 4, 3, 4, 3, 1, 3, 4, 3, 4, 3, 2, 4, 3, 2, 4, 3, 4, 4, 2, 3])

# %%
df31['sense of belonging _5'] = createe_groups(df21,'sense of belonging _5')

# %%
df31['sense of belonging _6'] = label.transform(df21["sense of belonging _6"])

# %%
df31['sense of belonging _7'] = createe_groups(df21,'sense of belonging _7')

# %%
df31['sense of belonging _8'] = createe_groups(df21,'sense of belonging _8')

# %%
df31['sense of belonging _10'] = createe_groups(df21,'sense of belonging _10')

# %%
df31['sense of belonging _11'] = createe_groups(df21,'sense of belonging _11')

# %%
df31['feelproud'] = createe_groups(df21,'feelproud')

# %%
df31['sense of belonging _16'] = createe_groups(df21,'sense of belonging _16')

# %%
df31
# Out:
#      sense of belonging _5  sense of belonging _6  sense of belonging _7  \
# 7                        4                      4                      4
# 8                        2                      2                      2
# 15                       4                      4                      3
# 16                       3                      3                      3
# 17                       4                      4                      4
# ..                     ...                    ...                    ...
# 236                      3                      1                      1
# 237                      4                      4                      3
# 238                      4                      4                      3
# 239                      2                      1                      2
# 240                      3                      4                      3
#
#      sense of belonging _8  sense of belonging _10  sense of belonging _11  \
# 7                        4                       4                       4
# 8                        2                       2                       2
# 15                       4                       2                       4
# 16                       3                       3                       3
# 17                       4                       4                       4
# ..                     ...                     ...                     ...
# 236                      1                       2                       1
# 237                      4                       4                       4
# 238                      4                       3                       4
# 239                      2                       1                       1
# 240                      3                       3                       3
#
#      feelproud  sense of belonging _16
# 7            4                       4
# 8            2                       2
# 15           4                       4
# 16           3                       3
# 17           4                       4
# ..         ...                     ...
# 236          1                       1
# 237          4                       4
# 238          3                       3
# 239          2                       1
# 240          3                       3
#
# [220 rows x 8 columns]

# %%
df31.describe().transpose()
# Out:
#                         count      mean       std  min  25%  50%  75%  max
# sense of belonging _5   220.0  2.900000  1.046412  0.0  2.0  3.0  4.0  4.0
# sense of belonging _6   220.0  3.259091  0.811537  0.0  3.0  3.0  4.0  4.0
# sense of belonging _7   220.0  2.931818  0.854687  0.0  2.0  3.0  4.0  4.0
# sense of belonging _8   220.0  3.240909  0.828245  0.0  3.0  3.0  4.0  4.0
# sense of belonging _10  220.0  2.918182  0.947304  0.0  2.0  3.0  4.0  4.0
# sense of belonging _11  220.0  3.163636  0.844291  0.0  3.0  3.0  4.0  4.0
# feelproud               220.0  3.095455  0.846684  0.0  3.0  3.0  4.0  4.0
# sense of belonging _16  220.0  3.213636  0.888689  0.0  3.0  3.0  4.0  4.0

# %%
dendrogram = sch.dendrogram(sch.linkage(df31, method  = "ward"))
plt.title('Dendrogram')
plt.xlabel('survey respondents')
plt.ylabel('Euclidean distances')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering 
hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage ='ward')

# %%
y_hc=hc.fit_predict(df31)

# %%
print(y_hc)
# Out:
# [1 0 1 2 1 2 2 0 1 2 2 0 0 2 1 2 2 1 1 2 0 0 1 0 2 2 0 1 1 0 0 0 1 2 0 1 0
#  2 1 2 1 2 0 0 2 1 2 0 0 2 1 0 2 1 0 0 1 2 2 1 1 2 1 2 0 0 0 2 0 0 0 1 2 2
#  0 2 2 0 1 1 2 1 1 0 0 0 1 1 1 1 2 1 1 0 2 2 2 2 1 2 1 2 2 2 1 0 1 1 0 0 2
#  2 2 1 1 1 2 1 0 1 1 1 2 2 1 0 0 2 0 1 2 2 0 2 0 0 2 1 2 1 1 0 0 0 2 0 1 2
#  2 0 1 2 0 1 1 2 1 1 1 0 0 0 0 2 0 1 0 2 0 0 2 1 1 0 1 0 2 0 1 1 1 2 1 1 2
#  0 1 1 2 0 2 1 2 0 0 2 1 0 0 2 2 2 2 0 0 2 2 2 1 2 1 1 1 0 1 0 1 2 0 2]

# %%
y_hc.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_484146/2790809591.py in <module>
# ----> 1 y_hc.info()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'

# %%
B = df31.iloc[y_hc==0,:]

# %%
B
# Out:
#      sense of belonging _5  sense of belonging _6  sense of belonging _7  \
# 8                        2                      2                      2
# 20                       3                      3                      3
# 24                       2                      2                      2
# 25                       0                      0                      0
# 33                       2                      2                      2
# ..                     ...                    ...                    ...
# 224                      3                      4                      3
# 225                      1                      4                      3
# 234                      2                      3                      3
# 236                      3                      1                      1
# 239                      2                      1                      2
#
#      sense of belonging _8  sense of belonging _10  sense of belonging _11  \
# 8                        2                       2                       2
# 20                       3                       2                       2
# 24                       2                       2                       2
# 25                       0                       0                       0
# 33                       2                       2                       2
# ..                     ...                     ...                     ...
# 224                      2                       2                       2
# 225                      3                       2                       2
# 234                      3                       3                       2
# 236                      1                       2                       1
# 239                      2                       1                       1
#
#      feelproud  sense of belonging _16
# 8            2                       2
# 20           3                       3
# 24           2                       3
# 25           0                       0
# 33           2                       2
# ..         ...                     ...
# 224          3                       2
# 225          3                       2
# 234          3                       3
# 236          1                       1
# 239          2                       1
#
# [70 rows x 8 columns]

# %%
C = df31.iloc[y_hc==1,:]

# %%
C
# Out:
#      sense of belonging _5  sense of belonging _6  sense of belonging _7  \
# 7                        4                      4                      4
# 15                       4                      4                      3
# 17                       4                      4                      4
# 21                       4                      3                      2
# 27                       2                      4                      4
# ..                     ...                    ...                    ...
# 231                      2                      3                      3
# 232                      4                      4                      4
# 233                      3                      3                      3
# 235                      4                      4                      4
# 237                      4                      4                      3
#
#      sense of belonging _8  sense of belonging _10  sense of belonging _11  \
# 7                        4                       4                       4
# 15                       4                       2                       4
# 17                       4                       4                       4
# 21                       4                       3                       3
# 27                       4                       4                       4
# ..                     ...                     ...                     ...
# 231                      4                       3                       3
# 232                      4                       4                       4
# 233                      4                       4                       3
# 235                      4                       4                       4
# 237                      4                       4                       4
#
#      feelproud  sense of belonging _16
# 7            4                       4
# 15           4                       4
# 17           4                       4
# 21           4                       4
# 27           4                       4
# ..         ...                     ...
# 231          4                       4
# 232          4                       4
# 233          4                       4
# 235          4                       4
# 237          4                       4
#
# [75 rows x 8 columns]

# %%
D = df31.iloc[y_hc==2,:]

# %%
D
# Out:
#      sense of belonging _5  sense of belonging _6  sense of belonging _7  \
# 16                       3                      3                      3
# 18                       4                      4                      3
# 19                       3                      4                      3
# 22                       3                      3                      3
# 23                       2                      4                      2
# ..                     ...                    ...                    ...
# 227                      4                      2                      3
# 228                      3                      3                      3
# 230                      3                      4                      3
# 238                      4                      4                      3
# 240                      3                      4                      3
#
#      sense of belonging _8  sense of belonging _10  sense of belonging _11  \
# 16                       3                       3                       3
# 18                       4                       2                       3
# 19                       4                       3                       3
# 22                       3                       3                       3
# 23                       4                       3                       4
# ..                     ...                     ...                     ...
# 227                      2                       3                       3
# 228                      4                       2                       3
# 230                      4                       3                       4
# 238                      4                       3                       4
# 240                      3                       3                       3
#
#      feelproud  sense of belonging _16
# 16           3                       3
# 18           3                       3
# 19           3                       3
# 22           3                       3
# 23           2                       4
# ..         ...                     ...
# 227          2                       4
# 228          3                       4
# 230          3                       3
# 238          3                       3
# 240          3                       3
#
# [75 rows x 8 columns]

# %%
B1 = B.mean()

# %%
B1
# Out:
# sense of belonging _5     1.971429
# sense of belonging _6     2.542857
# sense of belonging _7     2.328571
# sense of belonging _8     2.585714
# sense of belonging _10    2.100000
# sense of belonging _11    2.414286
# feelproud                 2.385714
# sense of belonging _16    2.357143
# dtype: float64

# %%
C1 = C.mean()
print(C1)
# Out:
# sense of belonging _5     3.440000
# sense of belonging _6     3.826667
# sense of belonging _7     3.546667
# sense of belonging _8     3.893333
# sense of belonging _10    3.666667
# sense of belonging _11    3.840000
# feelproud                 3.893333
# sense of belonging _16    3.933333
# dtype: float64

# %%
D1 = D.mean()
D1
# Out:
# sense of belonging _5     3.226667
# sense of belonging _6     3.360000
# sense of belonging _7     2.880000
# sense of belonging _8     3.200000
# sense of belonging _10    2.933333
# sense of belonging _11    3.186667
# feelproud                 2.960000
# sense of belonging _16    3.293333
# dtype: float64
